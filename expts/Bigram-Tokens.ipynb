# %%
import cv2
import numpy as np
import pandas as pd
import pytesseract as tess
from matplotlib import pyplot as plt

# %%
import Levenshtein as lev
from skimage.filters.rank import entropy
from pytesseract import Output

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/indra25/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def getCoordinates(row):
    left, top, width, height = row['left'], row['top'], row['width'], row['height']
    coord = (int(left + (width / 2)), int(top + (height / 2)))
    
    return coord

# %%
def getNeighbors(word, img, df , window_size):
    y_coord,x_coord = df[df['text'] == word].iloc[0][['y_coord','x_coord']]
    c1 = df['x_coord'].isin(range(x_coord-window_size,x_coord+window_size))
    c2 = df['y_coord'].isin(range(y_coord-window_size,y_coord+window_size))
    
    return list(df[c1 & c2].text)

# %%
def plot_patch(word, img, df , window_size):
    y_coord,x_coord, neighbors = df[df['text'] == word].iloc[0][['y_coord','x_coord','neighbors']]    
    patch_img = img[x_coord-window_size:x_coord+window_size,y_coord-window_size:y_coord+window_size]
    plt.imshow(patch_img)

# %%
def GenerateBigramTokens(img,min_conf=0,min_word_len=3,window=200):
    data = tess.image_to_data(img, output_type=tess.Output.DICT)
    df = pd.DataFrame(data)
    
    df.dropna(subset=['text'],inplace=True)
    
    filt = (df['conf'] > min_conf) & (df['text'].str.len() > min_word_len)
    idx = df[filt]['text'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words])).index
    df = df.iloc[idx]
    df.reset_index(inplace=True, drop=True)
    
    df[['y_coord','x_coord']] = df.apply(lambda x: getCoordinates(x),axis=1,result_type='expand')
    df['neighbors'] = df.apply(lambda x: getNeighbors(x.loc['text'],imgPDF,df,window),axis=1)

    TokenPairs = [(row['text'], item) for _, row in df.iterrows() for item in row['neighbors']]
    TokenPairs = [(x, y) for x, y in TokenPairs if x != y]    
    
    return set(TokenPairs)

# %%
imgPDF = cv2.imread('./../../samples/imgPDF.png')
imgPDF.shape
# Out:
# (1770, 1270, 3)

# %%
OriginalTokenPairs = GenerateBigramTokens(imgPDF)

# %%
img1 = cv2.imread('./../../samples/img3.jpeg')
img1.shape
# Out:
# (1280, 960, 3)

# %%
CapturedTokenPairs1 = GenerateBigramTokens(img1)

# %%
c = set( OriginalTokenPairs).intersection(set(CapturedTokenPairs1))
len(c),c
# Out:
# (2201,
#  {('Figure', 'during'),
#   ('solubility', 'limit'),
#   ('data', 'Baseline'),
#   ('levofloxacin,', 'biofilm'),
#   ('showed', 'experienced'),
#   ('taken', 'against'),
#   ('rifampin', 'increase'),
#   ('determining', 'Efforts'),
#   ('Phenotype', 'antimicrobial'),
#   ('biofilms', 'during'),
#   ('planktonic', 'between'),
#   ('attributed', 'biofilms'),
#   ('reduction', 'aBL.'),
#   ('shows', 'each'),
#   ('while', 'determined'),
#   ('substantial', '(2.4-4.8'),
#   ('mg/mL', 'reduction'),
#   ('while', 'controls'),
#   ('each', 'reduction'),
#   ('trend', 'different'),
#   ('mg/ml.', 'treatments.'),
#   ('biofilm', 'between'),
#   ('trend', 'during'),
#   ('decreases', 'between'),
#   ('nafcillin', 'effects'),
#   ('between', 'showed'),
#   ('against', 'biofilm'),
#   ('contrast,', 'Effect'),
#   ('limit', 'dose'),
#   ('while', 'trend'),
#   ('data', 'experienced'),
#   ('Percutaneous', 'antibiotic'),
#   ('dosage', 'attributed'),
#   ('experienced', 'side'),
#   ('against', 'levofloxacin,'),
#   ('when', '(2.4-4.8'),
#   ('pattern,', 'Both'),
#   ('attributed', 'test'),
#   ('aBL.', 'difference'),
#   ('with', 'noticeable'),
#   ('significant', 'MBCs'),
#   ('between', 'during'),
#   ('decrease', 'increases'),
#   ('increase', 'difference'),
#   ('with', 'first'),
#   ('upwards.', 'during'),
#   ('results', 'Both'),
#   ('adjusted', 'test'),
#   ('mg/ml.', 'limit'),
#   ('change', 'Efforts'),
#   ('with', 'when'),
#   ('disparity', 'levofloxacin'),
#   ('with', 'reached'),
#   ('rifampin', 'each'),
#   ('results', 'that'),
#   ('difference', 'dose'),
#   ('intrinsic', 'biofilm'),
#   ('first', 'while'),
#   ('obtained', 'planktonic'),
#   ('upwards.', 'efficacy'),
#   ('nafcillin', 'levofloxacin'),
#   ('side', 'first'),
#   ('difference', 'shows'),
#   ('have', 'against'),
#   ('treatments.', 'been'),
#   ('Phenotype', 'between'),
#   ('demonstrated', 'contrast,'),
#   ('mg/ml.', 'Percutaneous'),
#   ('with', 'showed'),
#   ('solubility', 'Efforts'),
#   ('3.3.', 'demonstrated'),
#   ('attributed', 'been'),
#   ('reduction', 'obtained'),
#   ('Bacterial', 'upwards.'),
#   ('attributed', 'Discussion'),
#   ('against', 'during'),
#   ('treatments.', 'biofilm'),
#   ('first', 'demonstrated'),
#   ('determined', 'increase'),
#   ('while', 'treatments.'),
#   ('adjusted', 'been'),
#   ('nafcillin', 'against'),
#   ('biofilm', 'planktonic'),
#   ('increases', 'solubility'),
#   ('Bacterial', 'antimicrobial'),
#   ('solubility', 'significant'),
#   ('noticeable', 'reduction'),
#   ('taken', 'biofilm'),
#   ('decrease', 'MBCs'),
#   ('nafcillin', 'experiments'),
#   ('between', 'Figure'),
#   ('unique', '(Table'),
#   ('effects', 'Both'),
#   ('treatments.', 'when'),
#   ('bactericidal', 'shows'),
#   ('effects', 'that'),
#   ('intrinsic', 'disparity'),
#   ('aBL.', 'while'),
#   ('decrease', 'have'),
#   ('dosage', 'MBCs'),
#   ('experienced', 'rifampin'),
#   ('demonstrated', 'different'),
#   ('increase', 'while'),
#   ('(Table', 'decrease'),
#   ('determining', 'substantial'),
#   ('demonstrated', 'during'),
#   ('showed', 'during'),
#   ('been', '(2.4-4.8'),
#   ('decrease', 'taken'),
#   ('treatments.', 'showed'),
#   ('obtained', 'Both'),
#   ('during', 'Baseline'),
#   ('increases', 'Both'),
#   ('dose', 'side'),
#   ('effects', 'data'),
#   ('while', 'limit'),
#   ('3.3.', 'Effect'),
#   ('decrease', 'obtained'),
#   ('determining', 'mg/ml),'),
#   ('each', 'contrast,'),
#   ('aBL.', 'demonstrated'),
#   ('Both', '(Table'),
#   ('side', 'difference'),
#   ('determining', 'increase'),
#   ('mg/ml.', 'Efforts'),
#   ('experiments', 'Both'),
#   ('increase', 'demonstrated'),
#   ('attributed', 'disparity'),
#   ('determined', 'each'),
#   ('treatments.', 'during'),
#   ('limit', 'controls'),
#   ('Discussion', 'intrinsic'),
#   ('data', 'during'),
#   ('significant', '(Table'),
#   ('decreases', 'Both'),
#   ('attributed', 'during'),
#   ('lacking', 'Discussion'),
#   ('first', 'aBL.'),
#   ('Phase', 'Bacterial'),
#   ('results', 'Baseline'),
#   ('rifampin,', 'upwards.'),
#   ('attributed', 'efficacy'),
#   ('experiments', 'data'),
#   ('have', 'biofilm'),
#   ('change', 'substantial'),
#   ('effects', 'trend'),
#   ('adjusted', 'during'),
#   ('disparity', 'been'),
#   ('demonstrated', 'Figure'),
#   ('(Table', 'between'),
#   ('first', 'nafcillin'),
#   ('nafcillin', 'been'),
#   ('dose', 'increase'),
#   ('trend', 'change'),
#   ('Efforts', 'dose'),
#   ('each', 'during'),
#   ('intrinsic', 'substantial'),
#   ('effects', 'with'),
#   ('when', 'with'),
#   ('trend', 'mg/ml.'),
#   ('rifampin,', 'MBCs'),
#   ('change', 'mg/ml),'),
#   ('disparity', 'biofilm'),
#   ('unique', 'Both'),
#   ('difference', 'effects'),
#   ('solubility', 'substantial'),
#   ('first', 'dosage'),
#   ('nafcillin', 'biofilm'),
#   ('during', 'Percutaneous'),
#   ('change', 'while'),
#   ('mg/ml),', 'intrinsic'),
#   ('contrast,', 'shows'),
#   ('results', 'experienced'),
#   ('shows', 'dose'),
#   ('antibiotic', 'levofloxacin'),
#   ('intrinsic', 'mg/ml),'),
#   ('Phenotype', 'Both'),
#   ('shows', 'planktonic'),
#   ('nafcillin', 'first'),
#   ('rifampin,', 'taken'),
#   ('effects', 'reduction'),
#   ('when', 'reduction'),
#   ('decrease', '(Table'),
#   ('solubility', 'mg/ml),'),
#   ('nafcillin', 'when'),
#   ('Both', 'rifampin,'),
#   ('Efforts', 'solubility'),
#   ('effects', 'Baseline'),
#   ('(2.4-4.8', 'dose'),
#   ('bactericidal', 'determined'),
#   ('noticeable', 'contrast,'),
#   ('dosage', '(Table'),
#   ('aBL.', 'adjusted'),
#   ('effects', 'biofilms'),
#   ('with', 'demonstrated'),
#   ('increase', 'adjusted'),
#   ('experiments', 'with'),
#   ('limit', 'treatments.'),
#   ('rifampin,', 'lacking'),
#   ('side', 'rifampin'),
#   ('reached', 'solubility'),
#   ('significant', 'rifampin,'),
#   ('difference', 'levofloxacin'),
#   ('nafcillin', 'showed'),
#   ('pattern,', 'been'),
#   ('bactericidal', 'effects'),
#   ('first', 'obtained'),
#   ('showed', 'increase'),
#   ('pattern,', 'Discussion'),
#   ('lacking', 'during'),
#   ('shows', 'solubility'),
#   ('Phase', 'rifampin,'),
#   ('noticeable', 'showed'),
#   ('upwards.', 'increases'),
#   ('taken', 'mg/ml),'),
#   ('lacking', 'efficacy'),
#   ('levofloxacin,', 'increases'),
#   ('experiments', 'reduction'),
#   ('(Table', 'planktonic'),
#   ('reduction', 'that'),
#   ('effects', 'experienced'),
#   ('been', 'trend'),
#   ('(2.4-4.8', 'solubility'),
#   ('mg/ml.', 'substantial'),
#   ('taken', 'while'),
#   ('experiments', 'Baseline'),
#   ('rifampin', 'shows'),
#   ('experiments', 'biofilms'),
#   ('Both', 'effects'),
#   ('noticeable', 'during'),
#   ('increase', 'determining'),
#   ('aBL.', 'have'),
#   ('substantial', 'Discussion'),
#   ('change', 'attributed'),
#   ('reduction', 'data'),
#   ('increase', 'have'),
#   ('Percutaneous', 'been'),
#   ('data', 'increase'),
#   ('difference', 'experiments'),
#   ('against', 'increases'),
#   ('bactericidal', 'levofloxacin'),
#   ('aBL.', 'taken'),
#   ('significant', 'effects'),
#   ('(Table', 'solubility'),
#   ('mg/ml),', 'dose'),
#   ('increase', 'taken'),
#   ('upwards.', 'antimicrobial'),
#   ('intrinsic', 'attributed'),
#   ('aBL.', 'obtained'),
#   ('reached', 'data'),
#   ('while', 'difference'),
#   ('Percutaneous', 'biofilm'),
#   ('experiments', 'experienced'),
#   ('determining', 'MBCs'),
#   ('increase', 'obtained'),
#   ('dosage', 'rifampin,'),
#   ('against', 'nafcillin'),
#   ('Figure', 'between'),
#   ('Efforts', 'determined'),
#   ('mg/mL', 'increase'),
#   ('have', 'substantial'),
#   ('with', 'aBL.'),
#   ('rifampin,', '(Table'),
#   ('each', 'increase'),
#   ('while', 'side'),
#   ('Bacterial', 'Both'),
#   ('determining', 'have'),
#   ('Both', 'levofloxacin'),
#   ('biofilms', 'between'),
#   ('unique', 'biofilms'),
#   ('treatments.', 'change'),
#   ('with', 'nafcillin'),
#   ('increases', 'Percutaneous'),
#   ('determining', 'taken'),
#   ('pattern,', 'during'),
#   ('against', 'dosage'),
#   ('have', 'mg/ml),'),
#   ('bactericidal', 'experiments'),
#   ('treatments.', 'mg/ml.'),
#   ('attributed', 'change'),
#   ('against', 'antimicrobial'),
#   ('shows', 'determined'),
#   ('difference', 'mg/mL'),
#   ('noticeable', 'Figure'),
#   ('levofloxacin,', 'taken'),
#   ('pattern,', 'efficacy'),
#   ('increases', 'Discussion'),
#   ('have', 'while'),
#   ('against', 'decrease'),
#   ('while', 'substantial'),
#   ('attributed', 'mg/ml.'),
#   ('effects', 'contrast,'),
#   ('data', 'each'),
#   ('when', 'contrast,'),
#   ('reduction', 'with'),
#   ('adjusted', 'change'),
#   ('(2.4-4.8', 'determined'),
#   ('limit', 'biofilm'),
#   ('3.2.', 'levofloxacin'),
#   ('treatments.', 'increases'),
#   ('shows', 'effects'),
#   ('antibiotic', 'biofilm'),
#   ('(2.4-4.8', 'controls'),
#   ('Percutaneous', 'disparity'),
#   ('adjusted', 'mg/ml.'),
#   ('been', 'test'),
#   ('determined', 'dose'),
#   ('Both', 'experiments'),
#   ('significant', 'treatments.'),
#   ('experienced', 'shows'),
#   ('bactericidal', 'unique'),
#   ('treatments.', 'aBL.'),
#   ('substantial', 'during'),
#   ('reached', 'with'),
#   ('limit', 'Efforts'),
#   ('shows', 'bactericidal'),
#   ('nafcillin', 'while'),
#   ('while', 'increase'),
#   ('significant', 'against'),
#   ('taken', 'increases'),
#   ('antibiotic', 'Efforts'),
#   ('mg/mL', 'each'),
#   ('when', 'showed'),
#   ('upwards.', 'between'),
#   ('substantial', 'efficacy'),
#   ('mg/ml.', 'attributed'),
#   ('change', 'have'),
#   ('treatments.', 'nafcillin'),
#   ('taken', 'aBL.'),
#   ('localized', 'test'),
#   ('different', 'mg/mL'),
#   ('rifampin,', 'Phase'),
#   ('(Table', 'controls'),
#   ('that', 'planktonic'),
#   ('aBL.', '(Table'),
#   ('change', 'taken'),
#   ('Effect', 'mg/mL'),
#   ('Figure', 'planktonic'),
#   ('reached', 'reduction'),
#   ('rifampin', 'determined'),
#   ('been', 'Percutaneous'),
#   ('solubility', 'MBCs'),
#   ('with', 'obtained'),
#   ('taken', 'nafcillin'),
#   ('intrinsic', 'have'),
#   ('biofilms', 'results'),
#   ('difference', 'noticeable'),
#   ('increase', '(Table'),
#   ('effects', 'during'),
#   ('treatments.', 'dosage'),
#   ('shows', 'levofloxacin'),
#   ('when', 'during'),
#   ('biofilms', 'planktonic'),
#   ('solubility', 'have'),
#   ('difference', 'first'),
#   ('intrinsic', 'taken'),
#   ('difference', 'when'),
#   ('difference', 'reached'),
#   ('antibiotic', 'disparity'),
#   ('against', 'between'),
#   ('rifampin', 'effects'),
#   ('treatments.', 'decrease'),
#   ('taken', 'dosage'),
#   ('solubility', 'taken'),
#   ('each', 'with'),
#   ('treatments.', 'determining'),
#   ('experiments', 'showed'),
#   ('have', 'attributed'),
#   ('Figure', 'solubility'),
#   ('determining', '(Table'),
#   ('shows', 'treatments.'),
#   ('difference', 'showed'),
#   ('mg/ml),', 'controls'),
#   ('taken', 'determining'),
#   ('3.2.', 'unique'),
#   ('efficacy', 'levofloxacin'),
#   ('first', 'that'),
#   ('taken', 'have'),
#   ('dosage', 'against'),
#   ('during', 'pattern,'),
#   ('experiments', 'during'),
#   ('Efforts', 'limit'),
#   ('(2.4-4.8', 'treatments.'),
#   ('between', 'results'),
#   ('nafcillin', 'change'),
#   ('have', 'increases'),
#   ('bactericidal', 'first'),
#   ('between', 'planktonic'),
#   ('different', 'Efforts'),
#   ('trend', 'solubility'),
#   ('experienced', 'rifampin,'),
#   ('rifampin', 'levofloxacin'),
#   ('have', 'aBL.'),
#   ('first', 'data'),
#   ('different', 'reached'),
#   ('reached', 'limit'),
#   ('effects', 'Figure'),
#   ('taken', 'obtained'),
#   ('when', 'Figure'),
#   ('have', 'adjusted'),
#   ('Effect', 'reached'),
#   ('Both', 'biofilm'),
#   ('dose', 'shows'),
#   ('localized', 'antibiotics'),
#   ('mg/ml.', 'have'),
#   ('unique', 'showed'),
#   ('shows', 'limit'),
#   ('different', '3.3.'),
#   ('determining', 'antibiotic'),
#   ('have', 'nafcillin'),
#   ('levofloxacin', 'rifampin,'),
#   ('(Table', 'treatments.'),
#   ('Effect', '3.3.'),
#   ('attributed', 'intrinsic'),
#   ('shows', 'unique'),
#   ('treatments.', 'between'),
#   ('test', 'dose'),
#   ('significant', 'biofilm'),
#   ('(2.4-4.8', 'limit'),
#   ('nafcillin', 'aBL.'),
#   ('experienced', 'determined'),
#   ('contrast,', 'mg/mL'),
#   ('been', 'during'),
#   ('mg/ml),', 'levofloxacin'),
#   ('side', 'shows'),
#   ('experienced', 'controls'),
#   ('nafcillin', 'adjusted'),
#   ('have', 'dosage'),
#   ('against', 'planktonic'),
#   ('limit', 'substantial'),
#   ('unique', 'during'),
#   ('determined', 'controls'),
#   ('side', '(Table'),
#   ('have', 'antimicrobial'),
#   ('been', 'efficacy'),
#   ('starting', 'solubility'),
#   ('rifampin', 'experiments'),
#   ('experiments', 'Figure'),
#   ('first', 'trend'),
#   ('al.,', 'antibiotics'),
#   ('experienced', 'effects'),
#   ('Both', 'showed'),
#   ('reduction', 'contrast,'),
#   ('have', 'determining'),
#   ('determined', 'effects'),
#   ('that', 'determined'),
#   ('levofloxacin,', 'Phase'),
#   ('solubility', '(Table'),
#   ('limit', 'mg/ml),'),
#   ('Figure', 'determined'),
#   ('(Table', 'limit'),
#   ('antimicrobial', 'mg/mL'),
#   ('mg/ml),', 'treatments.'),
#   ('antibiotic', 'mg/ml),'),
#   ('nafcillin', 'dosage'),
#   ('localized', 'efficacy'),
#   ('between', 'Both'),
#   ('determined', 'bactericidal'),
#   ('first', 'with'),
#   ('limit', 'while'),
#   ('decrease', 'been'),
#   ('between', 'that'),
#   ('showed', 'dose'),
#   ('demonstrated', 'planktonic'),
#   ('upwards.', 'Both'),
#   ('antibiotic', 'while'),
#   ('rifampin,', 'against'),
#   ('have', 'taken'),
#   ('showed', 'planktonic'),
#   ('that', 'effects'),
#   ('change', 'antibiotic'),
#   ('bactericidal', 'difference'),
#   ('test', 'antibiotic'),
#   ('nafcillin', 'determining'),
#   ('have', 'obtained'),
#   ('while', 'MBCs'),
#   ('trend', 'determined'),
#   ('that', 'bactericidal'),
#   ('decrease', 'biofilm'),
#   ('Figure', 'bactericidal'),
#   ('first', 'reduction'),
#   ('between', 'data'),
#   ('contrast,', 'noticeable'),
#   ('experienced', 'levofloxacin'),
#   ('substantial', 'mg/ml.'),
#   ('dosage', 'biofilm'),
#   ('determined', 'levofloxacin'),
#   ('first', 'Baseline'),
#   ('biofilms', 'bactericidal'),
#   ('unique', 'Figure'),
#   ('reduction', 'during'),
#   ('mg/ml),', 'limit'),
#   ('difference', 'while'),
#   ('Percutaneous', 'mg/ml.'),
#   ('treatments.', '(2.4-4.8'),
#   ('demonstrated', 'solubility'),
#   ('al.,', 'efficacy'),
#   ('treatments.', 'planktonic'),
#   ('contrast,', 'when'),
#   ('decrease', 'levofloxacin,'),
#   ('Bacterial', 'levofloxacin,'),
#   ('data', 'dose'),
#   ('showed', 'solubility'),
#   ('nafcillin', 'obtained'),
#   ('increases', 'pattern,'),
#   ('shows', 'reached'),
#   ('data', 'planktonic'),
#   ('contrast,', '3.3.'),
#   ('taken', '(2.4-4.8'),
#   ('that', 'levofloxacin'),
#   ('(2.4-4.8', 'Efforts'),
#   ('experienced', 'treatments.'),
#   ('determined', 'treatments.'),
#   ('Percutaneous', 'increases'),
#   ('with', 'that'),
#   ('pattern,', 'dosage'),
#   ('decrease', 'showed'),
#   ('mg/mL', 'dose'),
#   ('difference', 'demonstrated'),
#   ('mg/mL', 'shows'),
#   ('treatments.', 'solubility'),
#   ('experienced', 'experiments'),
#   ('each', 'planktonic'),
#   ('determined', 'experiments'),
#   ('aBL.', 'reduction'),
#   ('data', 'solubility'),
#   ('with', 'data'),
#   ('between', 'bactericidal'),
#   ('contrast,', 'different'),
#   ('antibiotic', 'attributed'),
#   ('dose', 'effects'),
#   ('increase', 'reduction'),
#   ('Discussion', 'significant'),
#   ('decrease', 'during'),
#   ('levofloxacin', 'experiments'),
#   ('during', 'intrinsic'),
#   ('rifampin', 'first'),
#   ('Discussion', 'decreases'),
#   ('reduction', 'Figure'),
#   ('that', 'experiments'),
#   ('adjusted', 'solubility'),
#   ('determined', 'limit'),
#   ('mg/ml.', 'antibiotic'),
#   ('Bacterial', 'efficacy'),
#   ('significant', 'substantial'),
#   ('(Table', 'significant'),
#   ('determined', 'unique'),
#   ('bactericidal', 'rifampin'),
#   ('limit', 'increases'),
#   ('substantial', 'decrease'),
#   ('each', 'solubility'),
#   ('when', 'nafcillin'),
#   ('antimicrobial', 'different'),
#   ('Both', '3.2.'),
#   ('treatments.', 'that'),
#   ('limit', 'aBL.'),
#   ('different', 'demonstrated'),
#   ('rifampin,', 'biofilm'),
#   ('antimicrobial', 'efficacy'),
#   ('limit', 'adjusted'),
#   ('Effect', 'demonstrated'),
#   ('Bacterial', 'Phenotype'),
#   ('shows', 'difference'),
#   ('levofloxacin', 'unique'),
#   ('Figure', 'limit'),
#   ('antibiotic', 'adjusted'),
#   ('demonstrated', 'determined'),
#   ('while', 'dose'),
#   ('solubility', 'effects'),
#   ('starting', 'levofloxacin'),
#   ('taken', 'that'),
#   ('mg/ml),', 'Efforts'),
#   ('that', 'unique'),
#   ('have', '(2.4-4.8'),
#   ('dose', 'levofloxacin'),
#   ('when', 'dosage'),
#   ('showed', 'determined'),
#   ('Figure', 'unique'),
#   ('levofloxacin,', 'Baseline'),
#   ('while', 'shows'),
#   ('rifampin,', 'levofloxacin,'),
#   ('shows', 'side'),
#   ('treatments.', 'data'),
#   ('showed', 'controls'),
#   ('while', '(Table'),
#   ('pattern,', 'between'),
#   ('effects', 'decrease'),
#   ('biofilms', 'unique'),
#   ('3.3.', 'contrast,'),
#   ('demonstrated', 'trend'),
#   ('contrast,', 'Figure'),
#   ('test', 'levofloxacin'),
#   ('showed', 'effects'),
#   ('difference', 'aBL.'),
#   ('trend', 'limit'),
#   ('antibiotic', 'dosage'),
#   ('nafcillin', '(2.4-4.8'),
#   ('first', 'contrast,'),
#   ('demonstrated', 'bactericidal'),
#   ('substantial', 'intrinsic'),
#   ('between', 'experienced'),
#   ('showed', 'bactericidal'),
#   ('against', 'Baseline'),
#   ('difference', 'nafcillin'),
#   ('Efforts', 'increase'),
#   ('noticeable', 'planktonic'),
#   ('limit', 'determining'),
#   ('antibiotics', 'al.,'),
#   ('data', 'determined'),
#   ('antibiotic', 'determining'),
#   ('with', 'reduction'),
#   ('different', 'Effect'),
#   ('levofloxacin,', 'experienced'),
#   ('data', 'controls'),
#   ('experienced', 'biofilm'),
#   ('limit', 'have'),
#   ('dose', 'experiments'),
#   ('substantial', 'between'),
#   ('with', 'Baseline'),
#   ('rifampin', 'difference'),
#   ('(2.4-4.8', 'substantial'),
#   ('while', 'antibiotic'),
#   ('determining', 'mg/mL'),
#   ('treatments.', 'trend'),
#   ('experiments', 'decrease'),
#   ('difference', 'dosage'),
#   ('adjusted', 'determined'),
#   ('limit', 'taken'),
#   ('data', 'effects'),
#   ('unique', 'aBL.'),
#   ('determined', 'first'),
#   ('showed', 'levofloxacin'),
#   ('starting', 'limit'),
#   ('side', 'biofilms'),
#   ('3.3.', 'different'),
#   ('each', 'determined'),
#   ('Discussion', 'substantial'),
#   ('limit', 'obtained'),
#   ('3.3.', 'during'),
#   ('noticeable', 'solubility'),
#   ('(2.4-4.8', 'mg/ml),'),
#   ('data', 'bactericidal'),
#   ('aBL.', 'noticeable'),
#   ('have', 'that'),
#   ('(2.4-4.8', 'increase'),
#   ('intrinsic', 'biofilms'),
#   ('first', 'during'),
#   ('effects', 'between'),
#   ('adjusted', 'trend'),
#   ('determined', 'significant'),
#   ('increase', 'noticeable'),
#   ('(Table', 'substantial'),
#   ('aBL.', 'contrast,'),
#   ('determining', 'been'),
#   ('increase', 'contrast,'),
#   ('shows', 'rifampin'),
#   ('contrast,', 'demonstrated'),
#   ('showed', 'treatments.'),
#   ('dose', 'mg/mL'),
#   ('been', 'decrease'),
#   ('treatments.', 'Baseline'),
#   ('nafcillin', 'that'),
#   ('determining', 'biofilm'),
#   ('data', 'levofloxacin'),
#   ('difference', 'obtained'),
#   ('aBL.', 'showed'),
#   ('significant', 'increases'),
#   ('mg/ml.', 'levofloxacin'),
#   ('different', 'antimicrobial'),
#   ('increase', 'showed'),
#   ('reached', 'each'),
#   ('taken', 'Baseline'),
#   ('intrinsic', 'test'),
#   ('experiments', 'between'),
#   ('determining', 'when'),
#   ('mg/ml),', 'substantial'),
#   ('nafcillin', 'data'),
#   ('antibiotics', 'localized'),
#   ('demonstrated', 'limit'),
#   ('mg/mL', 'levofloxacin'),
#   ('data', 'treatments.'),
#   ('each', 'levofloxacin'),
#   ('aBL.', 'during'),
#   ('noticeable', 'data'),
#   ('decrease', 'change'),
#   ('increase', 'during'),
#   ('first', 'Figure'),
#   ('showed', 'unique'),
#   ('treatments.', 'experienced'),
#   ('change', 'been'),
#   ('while', 'effects'),
#   ('determining', 'showed'),
#   ('determined', 'difference'),
#   ('dose', 'biofilm'),
#   ('adjusted', 'treatments.'),
#   ('Phase', 'upwards.'),
#   ('during', 'rifampin,'),
#   ('rifampin', 'demonstrated'),
#   ('been', 'intrinsic'),
#   ('mg/ml),', 'while'),
#   ('effects', 'dose'),
#   ('limit', '(Table'),
#   ('antibiotic', 'starting'),
#   ('determined', 'side'),
#   ('starting', 'Efforts'),
#   ('noticeable', 'determined'),
#   ('effects', 'planktonic'),
#   ('intrinsic', 'been'),
#   ('when', 'planktonic'),
#   ('dose', 'Efforts'),
#   ('dose', 'first'),
#   ('substantial', 'solubility'),
#   ('treatments.', 'limit'),
#   ('change', 'biofilm'),
#   ('intrinsic', 'Discussion'),
#   ('test', 'biofilm'),
#   ('dose', 'when'),
#   ('solubility', 'been'),
#   ('been', 'between'),
#   ('side', 'biofilm'),
#   ('Figure', 'difference'),
#   ('data', 'limit'),
#   ('contrast,', 'aBL.'),
#   ('with', 'contrast,'),
#   ('unique', 'between'),
#   ('significant', 'have'),
#   ('dosage', 'increases'),
#   ('decrease', 'aBL.'),
#   ('side', 'noticeable'),
#   ('Discussion', 'attributed'),
#   ('levofloxacin,', 'during'),
#   ('Both', 'obtained'),
#   ('that', 'side'),
#   ('data', 'unique'),
#   ('test', 'Efforts'),
#   ('Figure', 'side'),
#   ('antibiotic', '(2.4-4.8'),
#   ('side', 'contrast,'),
#   ('during', 'controls'),
#   ('while', 'levofloxacin'),
#   ('solubility', 'biofilm'),
#   ('dose', 'showed'),
#   ('significant', 'taken'),
#   ('adjusted', 'limit'),
#   ('nafcillin', 'with'),
#   ('decrease', 'nafcillin'),
#   ('side', 'when'),
#   ('noticeable', 'bactericidal'),
#   ('biofilms', 'side'),
#   ('have', 'Baseline'),
#   ('attributed', 'Percutaneous'),
#   ('effects', 'solubility'),
#   ('aBL.', 'Figure'),
#   ('when', 'solubility'),
#   ('results', 'rifampin,'),
#   ('mg/mL', 'limit'),
#   ('significant', 'obtained'),
#   ('noticeable', 'with'),
#   ('dosage', 'nafcillin'),
#   ('each', 'limit'),
#   ('increase', 'Figure'),
#   ('experiments', 'planktonic'),
#   ('solubility', 'first'),
#   ('upwards.', 'Phenotype'),
#   ('taken', 'been'),
#   ('solubility', 'when'),
#   ('side', 'showed'),
#   ('decrease', 'dosage'),
#   ('experienced', '3.2.'),
#   ('experienced', 'while'),
#   ('determined', 'while'),
#   ('disparity', 'biofilms'),
#   ('nafcillin', 'Baseline'),
#   ('with', 'during'),
#   ('dosage', 'antimicrobial'),
#   ('showed', 'first'),
#   ('decrease', 'determining'),
#   ('solubility', 'showed'),
#   ('antibiotics', 'levofloxacin'),
#   ('results', 'controls'),
#   ('levofloxacin', '3.2.'),
#   ('mg/ml),', 'attributed'),
#   ('when', 'that'),
#   ('Discussion', 'upwards.'),
#   ('bactericidal', '(Table'),
#   ('Figure', 'increase'),
#   ('different', 'starting'),
#   ('that', '3.2.'),
#   ('that', 'while'),
#   ('change', 'efficacy'),
#   ('against', 'Phenotype'),
#   ('between', 'side'),
#   ('taken', 'levofloxacin,'),
#   ('showed', 'significant'),
#   ('determined', 'rifampin'),
#   ('dosage', 'have'),
#   ('dose', 'difference'),
#   ('intrinsic', 'during'),
#   ('unique', 'results'),
#   ('biofilms', '3.2.'),
#   ('efficacy', 'antimicrobial'),
#   ('(2.4-4.8', 'have'),
#   ('contrast,', 'obtained'),
#   ('substantial', 'controls'),
#   ('unique', 'planktonic'),
#   ('mg/ml.', 'biofilm'),
#   ('intrinsic', 'efficacy'),
#   ('when', 'data'),
#   ('dosage', 'taken'),
#   ('nafcillin', 'experienced'),
#   ('rifampin,', 'increases'),
#   ('that', 'rifampin'),
#   ('data', 'Efforts'),
#   ('localized', 'al.,'),
#   ('trend', 'increase'),
#   ('Figure', 'rifampin'),
#   ('(2.4-4.8', 'taken'),
#   ('data', 'reached'),
#   ('determining', 'while'),
#   ('during', 'treatments.'),
#   ('increases', 'rifampin,'),
#   ('(Table', 'MBCs'),
#   ('experiments', 'that'),
#   ('Phenotype', 'Bacterial'),
#   ('have', 'been'),
#   ('effects', 'determined'),
#   ('when', 'determined'),
#   ('while', 'mg/mL'),
#   ('been', 'solubility'),
#   ('(Table', 'have'),
#   ('attributed', 'significant'),
#   ('with', 'Figure'),
#   ('effects', 'controls'),
#   ('mg/mL', 'Efforts'),
#   ('mg/mL', 'first'),
#   ('difference', 'that'),
#   ('decrease', 'between'),
#   ('results', 'levofloxacin'),
#   ('noticeable', 'limit'),
#   ('taken', 'during'),
#   ('Bacterial', 'between'),
#   ('each', 'reached'),
#   ('side', 'Figure'),
#   ('Figure', 'each'),
#   ('taken', 'efficacy'),
#   ('Discussion', 'lacking'),
#   ('determining', 'demonstrated'),
#   ('when', 'trend'),
#   ('3.2.', '(Table'),
#   ('dose', 'mg/ml),'),
#   ('rifampin,', 'dosage'),
#   ('biofilm', 'rifampin,'),
#   ('mg/ml.', 'disparity'),
#   ('showed', 'difference'),
#   ('disparity', 'Discussion'),
#   ('rifampin,', 'antimicrobial'),
#   ('increases', 'controls'),
#   ('difference', 'data'),
#   ('effects', 'bactericidal'),
#   ('during', 'limit'),
#   ('when', 'bactericidal'),
#   ('demonstrated', 'side'),
#   ('upwards.', 'pattern,'),
#   ('dose', 'while'),
#   ('rifampin', 'obtained'),
#   ('reduction', 'planktonic'),
#   ('rifampin,', 'decrease'),
#   ('showed', 'side'),
#   ('experiments', 'determined'),
#   ('test', 'mg/ml),'),
#   ('mg/ml),', 'have'),
#   ('unique', 'that'),
#   ('experienced', 'aBL.'),
#   ('Percutaneous', 'biofilms'),
#   ('while', 'biofilm'),
#   ('test', 'while'),
#   ('reached', 'shows'),
#   ('side', 'while'),
#   ('substantial', 'treatments.'),
#   ('mg/ml),', 'taken'),
#   ('determining', 'change'),
#   ('data', 'difference'),
#   ('dose', 'demonstrated'),
#   ('while', 'Efforts'),
#   ('while', 'first'),
#   ('shows', '(Table'),
#   ('unique', 'data'),
#   ('reduction', 'solubility'),
#   ('against', 'pattern,'),
#   ('results', 'planktonic'),
#   ('while', 'when'),
#   ('determining', 'mg/ml.'),
#   ('increase', 'aBL.'),
#   ('experiments', 'bactericidal'),
#   ('solubility', 'while'),
#   ('data', 'side'),
#   ('Phenotype', 'rifampin,'),
#   ('aBL.', 'nafcillin'),
#   ('pattern,', 'Percutaneous'),
#   ('decrease', 'results'),
#   ('Both', 'that'),
#   ('Efforts', 'antibiotic'),
#   ('results', 'unique'),
#   ('obtained', 'levofloxacin'),
#   ('contrast,', 'planktonic'),
#   ('antimicrobial', 'starting'),
#   ('have', 'during'),
#   ('increase', 'nafcillin'),
#   ('demonstrated', 'increase'),
#   ('decrease', 'planktonic'),
#   ('side', 'demonstrated'),
#   ('mg/mL', 'difference'),
#   ('effects', 'treatments.'),
#   ('lacking', 'significant'),
#   ('limit', 'Baseline'),
#   ('each', 'difference'),
#   ('while', 'showed'),
#   ('been', 'controls'),
#   ('difference', 'with'),
#   ('have', 'efficacy'),
#   ('experienced', 'MBCs'),
#   ('lacking', 'decreases'),
#   ('experienced', 'determining'),
#   ('efficacy', 'starting'),
#   ('substantial', 'limit'),
#   ('determined', 'MBCs'),
#   ('aBL.', 'dosage'),
#   ('rifampin,', 'between'),
#   ('determining', 'aBL.'),
#   ('solubility', 'demonstrated'),
#   ('increase', 'dosage'),
#   ('determining', 'adjusted'),
#   ('aBL.', 'decrease'),
#   ('nafcillin', 'during'),
#   ('increases', 'treatments.'),
#   ('substantial', 'Percutaneous'),
#   ('determining', 'nafcillin'),
#   ('aBL.', 'determining'),
#   ('demonstrated', 'rifampin'),
#   ('disparity', 'efficacy'),
#   ('difference', 'reduction'),
#   ('contrast,', 'solubility'),
#   ('rifampin', '(Table'),
#   ('showed', 'rifampin'),
#   ('decrease', 'solubility'),
#   ('treatments.', 'increase'),
#   ('(2.4-4.8', 'antibiotic'),
#   ('unique', 'bactericidal'),
#   ('experienced', 'obtained'),
#   ('when', 'limit'),
#   ('mg/ml.', 'mg/ml),'),
#   ('test', 'attributed'),
#   ('change', 'mg/ml.'),
#   ('Percutaneous', 'Discussion'),
#   ('effects', 'unique'),
#   ('determining', 'dosage'),
#   ('intrinsic', 'change'),
#   ('during', 'significant'),
#   ('Discussion', 'antibiotic'),
#   ('antibiotic', 'test'),
#   ('antimicrobial', 'solubility'),
#   ('levofloxacin,', 'dosage'),
#   ('dose', 'aBL.'),
#   ('solubility', 'change'),
#   ('adjusted', 'increase'),
#   ('intrinsic', 'mg/ml.'),
#   ('demonstrated', 'each'),
#   ('dose', 'adjusted'),
#   ('increases', 'limit'),
#   ('reduction', 'determined'),
#   ('solubility', 'mg/ml.'),
#   ('levofloxacin,', 'decrease'),
#   ('data', 'rifampin'),
#   ('dose', 'nafcillin'),
#   ('mg/mL', 'while'),
#   ('decrease', 'that'),
#   ('change', 'adjusted'),
#   ('dosage', 'that'),
#   ('side', 'aBL.'),
#   ('pattern,', 'significant'),
#   ('test', 'adjusted'),
#   ('bactericidal', 'biofilms'),
#   ('change', 'nafcillin'),
#   ('been', 'treatments.'),
#   ('limit', 'been'),
#   ('solubility', 'increases'),
#   ('aBL.', 'between'),
#   ('contrast,', 'data'),
#   ('experiments', 'unique'),
#   ('dose', 'dosage'),
#   ('antibiotic', 'been'),
#   ('side', 'nafcillin'),
#   ('taken', 'change'),
#   ('decrease', 'data'),
#   ('results', 'significant'),
#   ('determining', 'obtained'),
#   ('reduction', 'bactericidal'),
#   ('each', 'rifampin'),
#   ('solubility', 'aBL.'),
#   ('solubility', 'adjusted'),
#   ...})

# %%
def apply_rules(word):
    rules = {
        'ceoCDQ0': 'c',
        '7Zz': 'z',
        'YVyv': 'v',
        'IijJLl1': 'i',
        '9gq': 'g',
        'li': 'h',
        'f,t': 'f',
        '68': '6',
        'BEF': 'B',
        'ri': 'n',
        'tn': 'm',
        'rn': 'm',
        'nn': 'm',
        'cl': 'd',
        'el': 'd'
    }
    
    for rule, replacement in rules.items():
        word = word.replace(rule, replacement)
    return word
